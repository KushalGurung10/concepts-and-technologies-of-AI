# %% [markdown]
# <a href="https://colab.research.google.com/github/KushalGurung10/concepts-and-technologies-of-AI/blob/main/2462300_KushalGurung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/AI/Human_Development_Index_Dataset.csv", encoding="latin1")

# %%
df.head()
# Out:
#    Unnamed: 0 iso3      country  year    hdi  life_expectancy  pop_millions  \
# 0           1  AFG  Afghanistan  1990  0.284           45.967     10.694796
# 1           2  AFG  Afghanistan  1991  0.292           46.663     10.745167
# 2           3  AFG  Afghanistan  1992  0.299           47.596     12.057433
# 3           4  AFG  Afghanistan  1993  0.307           51.466     14.003760
# 4           5  AFG  Afghanistan  1994  0.300           51.495     15.455554
#
#    hdi_f  hdi_m  life_expec_f  ...  gender_development  gender_inequality  \
# 0    NaN    NaN        48.397  ...                 NaN                NaN
# 1    NaN    NaN        49.144  ...                 NaN                NaN
# 2    NaN    NaN        50.320  ...                 NaN                NaN
# 3    NaN    NaN        52.739  ...                 NaN                NaN
# 4    NaN    NaN        53.544  ...                 NaN                NaN
#
# ...

# %% [markdown]
# 3 Problem 1
#
# Basic Data Exploration & Trend Visualization
# 3.1 Problem - 1A - Single Year HDI Exploration (Latest Year: 2022)
#
# Tasks:
# 1. Extract Latest Year:

# %%
print("Unique Years:", df['year'].unique())
# Out:
# Unique Years: [1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022]

# %%
hdi_2022_df = df[df['year'] == 2022].copy()
hdi_2022_df.head(10)
# Out:
#      Unnamed: 0 iso3              country  year    hdi  life_expectancy  \
# 32           33  AFG          Afghanistan  2022  0.462           62.879
# 65           66  ALB              Albania  2022  0.789           76.833
# 98           99  DZA              Algeria  2022  0.745           77.129
# 131         132  AND              Andorra  2022  0.884           83.552
# 164         165  AGO               Angola  2022  0.591           61.929
# 197         198  ATG  Antigua and Barbuda  2022  0.826           79.236
# 230         231  ARG            Argentina  2022  0.849           76.064
# 263         264  ARM              Armenia  2022  0.786           73.372
# 296         297  AUS            Australia  2022  0.946           83.579
# 329         330  AUT              Austria  2022  0.926           82.412
#
#      pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 32      41.128771  0.332443  0.534145        66.213  ...               0.622
# ...

# %% [markdown]
# 2. Data Exploration:

# %%
hdi_2022_df.head(10)
# Out:
#      Unnamed: 0 iso3              country  year    hdi  life_expectancy  \
# 32           33  AFG          Afghanistan  2022  0.462           62.879
# 65           66  ALB              Albania  2022  0.789           76.833
# 98           99  DZA              Algeria  2022  0.745           77.129
# 131         132  AND              Andorra  2022  0.884           83.552
# 164         165  AGO               Angola  2022  0.591           61.929
# 197         198  ATG  Antigua and Barbuda  2022  0.826           79.236
# 230         231  ARG            Argentina  2022  0.849           76.064
# 263         264  ARM              Armenia  2022  0.786           73.372
# 296         297  AUS            Australia  2022  0.946           83.579
# 329         330  AUT              Austria  2022  0.926           82.412
#
#      pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 32      41.128771  0.332443  0.534145        66.213  ...               0.622
# ...

# %%
print("Rows, Columns:", hdi_2022_df.shape)
# Out:
# Rows, Columns: (206, 30)

# %%
hdi_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206 entries, 32 to 6797
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 206 non-null    int64
#  1   iso3                       206 non-null    object
#  2   country                    206 non-null    object
#  3   year                       206 non-null    int64
#  4   hdi                        204 non-null    float64
#  5   life_expectancy            206 non-null    float64
#  6   pop_millions               206 non-null    float64
#  7   hdi_f                      193 non-null    float64
#  8   hdi_m                      193 non-null    float64
#  9   life_expec_f               206 non-null    float64
#  10  life_expec_m               206 non-null    float64
#  11  expec_yr_school            205 non-null    float64
#  12  expec_yr_school_f          205 non-null    float64
# ...

# %% [markdown]
# 3. Missing Values & Data Cleaning:

# %%
print(hdi_2022_df.isnull().sum())
# Out:
# Unnamed: 0                    0
# iso3                          0
# country                       0
# year                          0
# hdi                           2
# life_expectancy               0
# pop_millions                  0
# hdi_f                        13
# hdi_m                        13
# life_expec_f                  0
# life_expec_m                  0
# expec_yr_school               1
# expec_yr_school_f             1
# expec_yr_school_m             1
# mean_yr_school                2
# mean_yr_school_f              2
# mean_yr_school_m              2
# gross_inc_percap              2
# gross_inc_percap_f           13
# gross_inc_percap_m           13
# gender_development           13
# gender_inequality            29
# secondary_education_f_%      17
# secondary_education_m_%      17
# seats_in_parliament_f_%       2
# seats_in_parliament_m_%       2
# labour_participation_f_%     12
# labour_participation_m_%     12
# co2_emission_tons             2
# ...

# %%
hdi_2022_df = hdi_2022_df.drop_duplicates()


hdi_2022_df['hdi'] = pd.to_numeric(hdi_2022_df['hdi'], errors='coerce')
hdi_2022_df['gross_inc_percap'] = pd.to_numeric(hdi_2022_df['gross_inc_percap'], errors='coerce')


hdi_2022_df = hdi_2022_df.dropna(subset=['hdi', 'gross_inc_percap'])

# %% [markdown]
# 4. Basic Statistics:

# %%
mean_hdi = hdi_2022_df['hdi'].mean()
median_hdi = hdi_2022_df['hdi'].median()
std_hdi = hdi_2022_df['hdi'].std()

print("Mean HDI:", mean_hdi)
print("Median HDI:", median_hdi)
print("Standard Deviation:", std_hdi)
# Out:
# Mean HDI: 0.7228872549019609
# Median HDI: 0.7395
# Standard Deviation: 0.15302880386427825

# %%
print("Highest HDI Country:", hdi_2022_df.loc[hdi_2022_df['hdi'].idxmax(), 'country'])
print("Lowest HDI Country:", hdi_2022_df.loc[hdi_2022_df['hdi'].idxmin(), 'country'])
# Out:
# Highest HDI Country: Switzerland
# Lowest HDI Country: Somalia

# %% [markdown]
# 5. Filtering and Sorting:

# %%
high_hdi_df = hdi_2022_df[hdi_2022_df['hdi'] > 0.800]

# %%
high_hdi_sorted = high_hdi_df.sort_values(
    by='gross_inc_percap',
    ascending=False
)

# %%
high_hdi_sorted[['country', 'hdi', 'gross_inc_percap']].head(10)
# Out:
#                      country    hdi  gross_inc_percap
# 3332           Liechtenstein  0.942      146673.24150
# 4718                   Qatar  0.875       95944.37754
# 5213               Singapore  0.949       88761.14559
# 2705                 Ireland  0.950       87467.51391
# 3398              Luxembourg  0.927       78554.23640
# 6104    United Arab Emirates  0.937       74103.71494
# 5609             Switzerland  0.967       69432.78669
# 4322                  Norway  0.966       69189.76165
# 6170           United States  0.927       65564.93798
# 2474  Hong Kong, China (SAR)  0.956       62485.50516

# %% [markdown]
# 6. Adding HDI Category Column:
# HDI Categories:
#
# Low < 0.550
#
# Medium 0.550 – 0.699
#
# High 0.700 – 0.799
#
# Very High ≥ 0.800

# %%
bins = [0, 0.550, 0.699, 0.799, 1.0]
labels = ['Low', 'Medium', 'High', 'Very High']

hdi_2022_df['HDI_Category'] = pd.cut(
    hdi_2022_df['hdi'],
    bins=bins,
    labels=labels,
    right=True,
    include_lowest=True
)

print(hdi_2022_df[['country', 'hdi', 'HDI_Category']].head(15))

hdi_2022_df.to_csv('HDI_category_added.csv', index=False)
# Out:
#                  country    hdi HDI_Category
# 32           Afghanistan  0.462          Low
# 65               Albania  0.789         High
# 98               Algeria  0.745         High
# 131              Andorra  0.884    Very High
# 164               Angola  0.591       Medium
# 197  Antigua and Barbuda  0.826    Very High
# 230            Argentina  0.849    Very High
# 263              Armenia  0.786         High
# 296            Australia  0.946    Very High
# 329              Austria  0.926    Very High
# 362           Azerbaijan  0.760         High
# 395              Bahamas  0.820    Very High
# 428              Bahrain  0.888    Very High
# 461           Bangladesh  0.670       Medium
# 494             Barbados  0.809    Very High

# %%
selected_countries = ['Afghanistan', 'Albania', 'India', 'Australia']

filtered_df = hdi_2022_df[
    hdi_2022_df['country'].isin(selected_countries)
]

plt.figure(figsize=(8,5))
plt.bar(filtered_df['country'], filtered_df['hdi'])
plt.xlabel('Country')
plt.ylabel('HDI Value')
plt.title('HDI Comparison of Selected Countries (2022)')
plt.show()

# %% [markdown]
# 3.2 Problem - 1B - HDI Visualization and Trend Analysis (2020 –

# %% [markdown]
# 1. Data Extraction and Saving:

# %%
hdi_2020_2022_df = df[df['year'].isin([2020, 2021, 2022])]


hdi_2020_2022_df.to_csv('/content/drive/MyDrive/AI/HDI_problem1B.csv', index=False)

# %% [markdown]
# 2. Data Cleaning:

# %%
hdi_2020_2022_df[['country', 'year', 'hdi']].isnull().sum()
# Out:
# country    0
# year       0
# hdi        8
# dtype: int64

# %%
hdi_2020_2022_df = hdi_2020_2022_df.dropna(subset=['hdi'])

# %%
hdi_2020_2022_df = hdi_2020_2022_df.drop_duplicates()

# %% [markdown]
# 3. Visualization Tasks:
#
# A. Line Chart — HDI Trend (Country-Level):

# %%
countries = ['Nepal','India','Pakistan','Bangladesh','Sri Lanka']
plt.figure(figsize=(8,5))
for country in countries:
    data = hdi_2020_2022_df[hdi_2020_2022_df['country']==country]
    plt.plot(data['year'], data['hdi'], marker='o', label=country)
plt.xlabel('Year')
plt.ylabel('HDI')
plt.title('HDI Trend (2020-2022)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# B. Generate Visualizations:
#
# – Bar Chart: Average HDI by Region (2020–2022)

# %%
#B. Generate Visualizations:
#Bar Chart: Average HDI by Region (2020–2022)
"Since there is not 'region' column in the given dataset, we will need to create one to complete this task."

region_map = {
    #South-Asia
    'Afghanistan': 'South Asia',
    'Bangladesh': 'South Asia',
    'Bhutan': 'South Asia',
    'India': 'South Asia',
    'Maldives': 'South Asia',
    'Nepal': 'South Asia',
    'Pakistan': 'South Asia',
    'Sri Lanka': 'South Asia',

    #East-Asia and Pacific
    'China': 'East Asia & Pacific',
    'Japan': 'East Asia & Pacific',
    'Australia': 'East Asia & Pacific',
    'New Zealand': 'East Asia & Pacific',
    'Indonesia': 'East Asia & Pacific',
    'Philippines': 'East Asia & Pacific',
    'South Korea': 'East Asia & Pacific',
    'Thailand': 'East Asia & Pacific',

    #Europe and Central Asia
    'Germany': 'Europe & Central Asia',
    'France': 'Europe & Central Asia',
    'United Kingdom': 'Europe & Central Asia',
    'Russia': 'Europe & Central Asia',
    'Italy': 'Europe & Central Asia',
    'Spain': 'Europe & Central Asia',

    #Latin America and Caribbean
    'Brazil': 'Latin America & Caribbean',
    'Mexico': 'Latin America & Caribbean',
    'Argentina': 'Latin America & Caribbean',
    'Chile': 'Latin America & Caribbean',
    'Colombia': 'Latin America & Caribbean',

    #Sub-Saharan Africa
    'Nigeria': 'Sub-Saharan Africa',
    'South Africa': 'Sub-Saharan Africa',
    'Kenya': 'Sub-Saharan Africa',
    'Ghana': 'Sub-Saharan Africa',
    'Ethiopia': 'Sub-Saharan Africa',

    #North America
    'United States': 'North America',
    'Canada': 'North America',

    #Arab States
    'Egypt': 'Arab States',
    'Saudi Arabia': 'Arab States',
    'United Arab Emirates': 'Arab States',
    'Jordan': 'Arab States',
}
hdi_2020_2022_df['region'] = hdi_2020_2022_df['country'].map(region_map)
hdi_region = hdi_2020_2022_df.dropna(subset=['region'])
hdi_region[['country', 'region']].drop_duplicates().head(20)
# Out:
#           country                     region
# 30    Afghanistan                 South Asia
# 228     Argentina  Latin America & Caribbean
# 294     Australia        East Asia & Pacific
# 459    Bangladesh                 South Asia
# 657        Bhutan                 South Asia
# 789        Brazil  Latin America & Caribbean
# 1053       Canada              North America
# 1152        Chile  Latin America & Caribbean
# 1185        China        East Asia & Pacific
# 1218     Colombia  Latin America & Caribbean
# 1713        Egypt                Arab States
# 1911     Ethiopia         Sub-Saharan Africa
# 2010       France      Europe & Central Asia
# 2142      Germany      Europe & Central Asia
# 2175        Ghana         Sub-Saharan Africa
# 2571        India                 South Asia
# 2604    Indonesia        East Asia & Pacific
# 2769        Italy      Europe & Central Asia
# 2835        Japan        East Asia & Pacific
# 2868       Jordan                Arab States

# %%
region_hdi = hdi_region.groupby(['region', 'year'])['hdi'].mean().unstack()
plt.figure(figsize=(12,6))

region_hdi.plot(kind='bar')

plt.xlabel('Region')
plt.ylabel('Average HDI')
plt.title('Average HDI by Region (2020-2022)')
plt.xticks(rotation=45, ha='right')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Year')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# Box Plot: HDI Distribution for 2020, 2021, and 2022

# %%
sns.boxplot(x='year', y='hdi', data=hdi_2020_2022_df)
plt.title('HDI Distribution 2020-2022')
plt.show()

# %% [markdown]
# Scatter Plot: HDI vs. GNI per Capita

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(
    data=hdi_2020_2022_df,
    x='gross_inc_percap',
    y='hdi'
)

plt.xlabel("GNI per Capita")
plt.ylabel("HDI")
plt.title("HDI vs GNI per Capita (2020–2022)")
plt.show()

# %% [markdown]
# 4. Short Analysis Questions:

# %%
hdi_change = (
    hdi_2020_2022_df
    .pivot(index='country', columns='year', values='hdi')
)

hdi_change['change_2020_2022'] = hdi_change[2022] - hdi_change[2020]

hdi_change.sort_values('change_2020_2022', ascending=False).head(5)
# Out:
# year         2020   2021   2022  change_2020_2022
# country
# Andorra     0.843  0.855  0.884             0.041
# Azerbaijan  0.722  0.738  0.760             0.038
# Ecuador     0.734  0.746  0.765             0.031
# Maldives    0.737  0.753  0.762             0.025
# Mexico      0.757  0.757  0.781             0.024

# %%
hdi_change.sort_values('change_2020_2022').head(5)
# Out:
# year          2020   2021   2022  change_2020_2022
# country
# Timor-Leste  0.633  0.574  0.566            -0.067
# Ukraine      0.762  0.755  0.734            -0.028
# Afghanistan  0.488  0.473  0.462            -0.026
# Namibia      0.634  0.616  0.610            -0.024
# Lebanon      0.742  0.725  0.723            -0.019

# %% [markdown]
# 4 Problem 2
#
# Advanced HDI Exploration
#
# 1. Create South Asia Subset:

# %%
south_asia_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Sri Lanka"]
sa_df = df[df['country'].isin(south_asia_countries)]
sa_df.to_csv('/content/drive/MyDrive/AI/HDI_SouthAsia.cs', index=False)

# %% [markdown]
# 2. Composite Development Score:

# %%
sa_df = sa_df.copy()
sa_df['Composite Score'] = 0.3 * sa_df['life_expectancy'] + 0.3 * sa_df['gross_inc_percap']
sa_top5 = sa_df.sort_values('Composite Score', ascending=False).head(5)


plt.figure(figsize=(6,4))
plt.barh(sa_top5['country'], sa_top5['Composite Score'])
plt.xlabel('Composite Score')
plt.title('Top 5 South Asian Countries by Composite Score')
plt.show()

# %% [markdown]
# 3. Outlier Detection:

# %%
Q1 = sa_df['hdi'].quantile(0.25)
Q3 = sa_df['hdi'].quantile(0.75)
IQR = Q3 - Q1
outliers_hdi = sa_df[(sa_df['hdi'] < Q1 - 1.5*IQR) | (sa_df['hdi'] > Q3 + 1.5*IQR)]

plt.scatter(sa_df['gross_inc_percap'], sa_df['hdi'], color='blue')
plt.scatter(outliers_hdi['gross_inc_percap'], outliers_hdi['hdi'], color='red')
plt.xlabel('GNI per Capita')
plt.ylabel('HDI')
plt.title('HDI vs GNI per Capita (Outliers in Red)')
plt.show()

# %% [markdown]
# 4. Exploring Metric Relationships:

# %%
from scipy.stats import pearsonr


if 'gender_development' in sa_df.columns:

    filtered_df = sa_df.dropna(subset=['gender_development', 'hdi'])
    if not filtered_df.empty:
        corr, _ = pearsonr(filtered_df['gender_development'], filtered_df['hdi'])
        print("Pearson correlation (Gender Development vs HDI):", corr)
    else:
        print("Cannot compute correlation: insufficient non-null data after filtering.")
else:
    print("'gender_development' column not found in DataFrame.")
# Out:
# Pearson correlation (Gender Development vs HDI): 0.8656210050127544

# %% [markdown]
# 5. Gap Analysis:

# %%
sa_df = sa_df.copy()
sa_df['GNI_HDI_Gap'] = sa_df['gross_inc_percap'] - sa_df['hdi']
gap_top3 = sa_df.sort_values('GNI_HDI_Gap', ascending=False).head(3)
gap_bottom3 = sa_df.sort_values('GNI_HDI_Gap').head(3)

print("\nTop 3 GNI-HDI Gap Countries (Positive):\n", gap_top3[['country','GNI_HDI_Gap']])
print("\nTop 3 GNI-HDI Gap Countries (Negative):\n", gap_bottom3[['country','GNI_HDI_Gap']])
# Out:
# Top 3 GNI-HDI Gap Countries (Positive):
#         country  GNI_HDI_Gap
# 3530  Maldives  18846.03019
# 3527  Maldives  18679.17236
# 3526  Maldives  18054.97765
#
# Top 3 GNI-HDI Gap Countries (Negative):
#          country  GNI_HDI_Gap
# 11  Afghanistan   980.789554
# 10  Afghanistan  1047.002686
# 9   Afghanistan  1121.985570

# %% [markdown]
# 5 Problem 3
#
# Comparative Regional Analysis: South Asia vs Middle East
#
# 1. Create Middle East Subset:

# %%
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan",
                         "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar",
                         "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]


sa_2020_2022 = hdi_2020_2022_df[hdi_2020_2022_df['country'].isin(south_asia_countries)]
me_2020_2022 = hdi_2020_2022_df[hdi_2020_2022_df['country'].isin(middle_east_countries)]

sa_2020_2022.to_csv("/content/drive/MyDrive/AI/HDI_SouthAsia_2020_2022.csv", index=False)
me_2020_2022.to_csv("/content/drive/MyDrive/AI/HDI_MiddleEast_2020_2022.csv", index=False)

# %% [markdown]
# 2. Descriptive Statistics

# %%
print("Descriptive Statistics:")
print("South Asia HDI Mean:", sa_2020_2022['hdi'].mean(),
      "Standard Deviation:", sa_2020_2022['hdi'].std())
print("Middle East HDI Mean:", me_2020_2022['hdi'].mean(),
      "Standard Deviation:", me_2020_2022['hdi'].std())
# Out:
# Descriptive Statistics:
# South Asia HDI Mean: 0.6395833333333333 Standard Deviation: 0.09827331747496995
# Middle East HDI Mean: 0.7889090909090909 Standard Deviation: 0.14129476362297624

# %% [markdown]
# and 3. Top and Bottom Performers:

# %%
sa_top3 = sa_2020_2022.groupby('country')['hdi'].mean().sort_values(ascending=False).head(3)
sa_bottom3 = sa_2020_2022.groupby('country')['hdi'].mean().sort_values().head(3)

me_top3 = me_2020_2022.groupby('country')['hdi'].mean().sort_values(ascending=False).head(3)
me_bottom3 = me_2020_2022.groupby('country')['hdi'].mean().sort_values().head(3)

print("\nSouth Asia Top 3 Countries by HDI:\n", sa_top3)
print("\nSouth Asia Bottom 3 Countries by HDI:\n", sa_bottom3)
print("\nMiddle East Top 3 Countries by HDI:\n", me_top3)
print("\nMiddle East Bottom 3 Countries by HDI:\n", me_bottom3)
# Out:
# South Asia Top 3 Countries by HDI:
#  country
# Sri Lanka    0.780000
# Maldives     0.750667
# Bhutan       0.677667
# Name: hdi, dtype: float64
#
# South Asia Bottom 3 Countries by HDI:
#  country
# Afghanistan    0.474333
# Pakistan       0.537667
# Nepal          0.595000
# Name: hdi, dtype: float64
#
# Middle East Top 3 Countries by HDI:
#  country
# United Arab Emirates    0.932667
# Israel                  0.910667
# Bahrain                 0.885333
# Name: hdi, dtype: float64
#
# Middle East Bottom 3 Countries by HDI:
#  country
# Yemen      0.426333
# Iraq       0.667000
# Lebanon    0.730000
# Name: hdi, dtype: float64

# %% [markdown]
# 4. Metric Comparisons:

# %%
metrics = ['life_expectancy', 'gross_inc_percap', 'gender_development']

south_means = sa_2020_2022[metrics].mean()
middle_means = me_2020_2022[metrics].mean()


comparison_df = pd.DataFrame({
    'South Asia': south_means,
    'Middle East': middle_means
})

comparison_df.plot(kind='bar', figsize=(8,5))
plt.title("Metric Comparison: South Asia vs Middle East (2020-2022)")
plt.ylabel("Average Value")
plt.xlabel("Metric")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 5. HDI Disparity:

# %%
south_range = sa_2020_2022['hdi'].max() - sa_2020_2022['hdi'].min()
middle_range = me_2020_2022['hdi'].max() - me_2020_2022['hdi'].min()

south_cv = sa_2020_2022['hdi'].std() / sa_2020_2022['hdi'].mean()
middle_cv = me_2020_2022['hdi'].std() / me_2020_2022['hdi'].mean()

print(f"South Asia HDI Range: {south_range:.3f}")
print(f"Middle East HDI Range: {middle_range:.3f}")
print(f"South Asia HDI Coefficient of Variation: {south_cv:.3f}")
print(f"Middle East HDI Coefficient of Variation: {middle_cv:.3f}")
# Out:
# South Asia HDI Range: 0.321
# Middle East HDI Range: 0.513
# South Asia HDI Coefficient of Variation: 0.154
# Middle East HDI Coefficient of Variation: 0.179

# %% [markdown]
# 6. Correlation Analysis:

# %%
south_corr_life = sa_2020_2022[['hdi', 'life_expectancy']].corr()
middle_corr_life = me_2020_2022[['hdi', 'life_expectancy']].corr()

south_corr_gni = sa_2020_2022[['hdi', 'gross_inc_percap']].corr()
middle_corr_gni = me_2020_2022[['hdi', 'gross_inc_percap']].corr()

print("\nSouth Asia HDI vs Life Expectancy Correlation:\n", south_corr_life)
print("\nMiddle East HDI vs Life Expectancy Correlation:\n", middle_corr_life)

print("\nSouth Asia HDI vs GNI per Capita Correlation:\n", south_corr_gni)
print("\nMiddle East HDI vs GNI per Capita Correlation:\n", middle_corr_gni)
# Out:
# South Asia HDI vs Life Expectancy Correlation:
#                        hdi  life_expectancy
# hdi              1.000000         0.938764
# life_expectancy  0.938764         1.000000
#
# Middle East HDI vs Life Expectancy Correlation:
#                        hdi  life_expectancy
# hdi              1.000000         0.933123
# life_expectancy  0.933123         1.000000
#
# South Asia HDI vs GNI per Capita Correlation:
#                        hdi  gross_inc_percap
# hdi               1.00000           0.88653
# gross_inc_percap  0.88653           1.00000
#
# Middle East HDI vs GNI per Capita Correlation:
#                         hdi  gross_inc_percap
# hdi               1.000000          0.756826
# gross_inc_percap  0.756826          1.000000

# %% [markdown]
# 7. Outlier Detection:

# %%
Q1_south = sa_2020_2022['hdi'].quantile(0.25)
Q3_south = sa_2020_2022['hdi'].quantile(0.75)
IQR_south = Q3_south - Q1_south

outliers_south = sa_2020_2022[
    (sa_2020_2022['hdi'] < Q1_south - 1.5 * IQR_south) |
    (sa_2020_2022['hdi'] > Q3_south + 1.5 * IQR_south)
]

print("\nSouth Asia HDI Outliers:\n", outliers_south[['country', 'year', 'hdi']])


Q1_middle = me_2020_2022['hdi'].quantile(0.25)
Q3_middle = me_2020_2022['hdi'].quantile(0.75)
IQR_middle = Q3_middle - Q1_middle

outliers_middle = me_2020_2022[
    (me_2020_2022['hdi'] < Q1_middle - 1.5 * IQR_middle) |
    (me_2020_2022['hdi'] > Q3_middle + 1.5 * IQR_middle)
]

print("\nMiddle East HDI Outliers:\n", outliers_middle[['country', 'year', 'hdi']])



plt.figure(figsize=(8,5))

plt.scatter(sa_2020_2022['gross_inc_percap'], sa_2020_2022['hdi'], color='blue', label='South Asia')
plt.scatter(outliers_south['gross_inc_percap'], outliers_south['hdi'], color='red', label='South Asia Outliers', marker='x')

plt.scatter(me_2020_2022['gross_inc_percap'], me_2020_2022['hdi'], color='green', label='Middle East')
plt.scatter(outliers_middle['gross_inc_percap'], outliers_middle['hdi'], color='orange', label='Middle East Outliers', marker='x')

plt.xlabel('GNI per Capita')
plt.ylabel('HDI')
plt.title('HDI vs GNI per Capita with Outliers Highlighted')
plt.legend()
plt.show()
# Out:
# South Asia HDI Outliers:
#  Empty DataFrame
# Columns: [country, year, hdi]
# Index: []
#
# Middle East HDI Outliers:
#       country  year    hdi
# 6366   Yemen  2020  0.430
# 6367   Yemen  2021  0.425
# 6368   Yemen  2022  0.424
